# %% [markdown]
# <a href="https://colab.research.google.com/github/maiahmed10/Python-Labs/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def solution(inputString):
    if inputString == inputString[::-1]:
        return True
    else:
        return False


print(solution("aabaa"))
print(solution("abac"))
print(solution("a"))
# Out:
# True
# False
# True

# %%
lst1 = [1, 2, 3]
lst2 = [4, 5, 6]

result = lst1 + lst2

print(result)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
names = ["Ahmed", "Amani","Sara", "Samar", "Omar", "Ola","mai"]

result = {}

for i in names:
    alpha = i[0]

    if alpha not in result:
        result[alpha] = []

    result[alpha].append(i)

result = dict(sorted(result.items()))

print(result)
# Out:
# {'A': ['Ahmed', 'Amani'], 'O': ['Omar', 'Ola'], 'S': ['Sara', 'Samar'], 'm': ['mai']}

# %%
name = input("Enter your name: ")

while name == "" or name.isdigit():
    print("Invalid name!")
    name = input("Enter your name again: ")

email = input("Enter your email: ")

if "@" in email and "." in email:
    print("Valid email")
else:
    print("Invalid email")
    email= input(" Enter your email again .. ")

print("Name:", name)
print("Email:", email)
# Out:
# Enter your name:
# Invalid name!
# Enter your name again: Mai
# Enter your email: P
# Invalid email
#  Enter your email again .. Mai@yahoo.com
# Name: Mai
# Email: Mai@yahoo.com
