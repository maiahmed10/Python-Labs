# %% [markdown]
# <a href="https://colab.research.google.com/github/maiahmed10/Python-Labs/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab_2

# %%
text = "mai ahmed"

count = 0

for char in text:
    if char in "aeiou":
        count += 1

print(count)
# Out:
# 4

# %%
text = "hello mai"

if "i" in text:
    print(text.find("i"))
else:
    print("i not found")
# Out:
# 8

# %%
inputArray = ["aba", "aa", "ad", "vcd", "aba"]

max_length = 0

for word in inputArray:
    if len(word) > max_length:
        max_length = len(word)

result = []

for word in inputArray:
    if len(word) == max_length:
        result.append(word)

print(result)
# Out:
# ['aba', 'vcd', 'aba']

# %%
apple = [10, 20, 30]
capacity = [15, 25, 40, 10]

total_apples = sum(apple)

capacity.sort(reverse=True)

total_capacity = 0
boxes = 0

for c in capacity:
    total_capacity += c
    boxes += 1

    if total_capacity >= total_apples:
        break

print(boxes)
# Out:
# 2

# %% [markdown]
# To-Do app

# %%
tasks = []



def add_task():
    task = input("Enter a new task: ")
    tasks.append({"task": task, "done": False})
    print("Task added successfully!")


def view_tasks():
    if len(tasks) == 0:
        print("No tasks found.")
        return

    for i in range(len(tasks)):
        status = "DONE" if tasks[i]["done"] else "NOT DONE"
        print(i + 1, "-", tasks[i]["task"], "-->", status)



def update_task():
    view_tasks()

    index = int(input("Enter task number to update: "))

    if index >= 1 and index <= len(tasks):
        new_task = input("Enter new task: ")
        tasks[index - 1]["task"] = new_task
        print("Task updated successfully!")
    else:
        print("Invalid task number.")

def delete_task():
    view_tasks()

    index = int(input("Enter task number to delete: "))

    if index >= 1 and index <= len(tasks):
        tasks.pop(index - 1)
        print("Task deleted successfully!")
    else:
        print("Invalid task number.")



def mark_done():
    view_tasks()

    index = int(input("Enter task number to mark as done: "))

    if index >= 1 and index <= len(tasks):
        tasks[index - 1]["done"] = True
        print("Task marked as DONE!")
    else:
        print("Invalid task number.")



while True:

    print("\n===== TO-DO APPLICATION =====")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Update Task")
    print("4. Delete Task")
    print("5. Mark Task as Done")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_task()

    elif choice == "2":
        view_tasks()

    elif choice == "3":
        update_task()

    elif choice == "4":
        delete_task()

    elif choice == "5":
        mark_done()

    elif choice == "6":
        print("Goodbye!")
        break

    else:
        print("Invalid choice.")
# Out:
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 1
# Enter a new task: Web python
# Task added successfully!
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 1
# Enter a new task: Java
# Task added successfully!
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 1
# Enter a new task: Js
# Task added successfully!
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 2
# 1 - Web python --> NOT DONE
# 2 - Java --> NOT DONE
# 3 - Js --> NOT DONE
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 3
# 1 - Web python --> NOT DONE
# 2 - Java --> NOT DONE
# 3 - Js --> NOT DONE
# Enter task number to update: 1
# Enter new task: Web
# Task updated successfully!
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 2
# 1 - Web --> NOT DONE
# 2 - Java --> NOT DONE
# 3 - Js --> NOT DONE
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 4
# 1 - Web --> NOT DONE
# 2 - Java --> NOT DONE
# 3 - Js --> NOT DONE
# Enter task number to delete: 2
# Task deleted successfully!
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 5
# 1 - Web --> NOT DONE
# 2 - Js --> NOT DONE
# Enter task number to mark as done: 1
# Task marked as DONE!
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 2
# 1 - Web --> DONE
# 2 - Js --> NOT DONE
#
# ===== TO-DO APPLICATION =====
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Delete Task
# 5. Mark Task as Done
# 6. Exit
# Enter your choice: 6
# Goodbye!
